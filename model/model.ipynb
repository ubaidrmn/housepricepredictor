# %%
import pandas as pd
import numpy as np
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
import joblib

# %%
# Read the dataset
dataset = pd.read_csv("./data.csv")
dataset = dataset.iloc[:, 1:]
dataset = dataset.loc[(dataset.purpose == "For Sale")]
dataset = dataset.drop('purpose', axis=1)
dataset.head()
# Out:
#   property_type     price     location       city  baths  bedrooms  \
# 0          Flat  10000000         G-10  Islamabad      2         2
# 1          Flat   6900000         E-11  Islamabad      3         3
# 2         House  16500000         G-15  Islamabad      6         5
# 3         House  43500000    Bani Gala  Islamabad      4         4
# 4         House   7000000  DHA Defence  Islamabad      3         3
#
#    Area_in_Marla
# 0            4.0
# 1            5.6
# 2            8.0
# 3           40.0
# 4            8.0

# %%
y = dataset['price'].values
X = dataset.drop('price', axis=1).values
print(X, y)
# Out:
# [['Flat' 'G-10' 'Islamabad' 2 2 4.0]
#  ['Flat' 'E-11' 'Islamabad' 3 3 5.6]
#  ['House' 'G-15' 'Islamabad' 6 5 8.0]
#  ...
#  ['House' 'Bahria Town Karachi' 'Karachi' 3 3 8.0]
#  ['House' 'Bahria Town Karachi' 'Karachi' 4 4 14.0]
#  ['House' 'Bahria Town Karachi' 'Karachi' 3 3 9.4]] [10000000  6900000 16500000 ... 14000000 14000000  9000000]

# %%
sc = StandardScaler()
sc = sc.fit(X[:, 3:])
X[:, 3:] = sc.transform(X[:, 3:])
print(X)
# Out:
# [['Flat' 'G-10' 'Islamabad' -1.087524769501409 -1.148974938101838
#   -0.5849708515162284]
#  ['Flat' 'E-11' 'Islamabad' -0.4227711783150659 -0.3542752068465506
#   -0.31347698415512454]
#  ['House' 'G-15' 'Islamabad' 1.5714895952439636 1.235124255664024
#   0.09376381688653136]
#  ...
#  ['House' 'Bahria Town Karachi' 'Karachi' -0.4227711783150659
#   -0.3542752068465506 0.09376381688653136]
#  ['House' 'Bahria Town Karachi' 'Karachi' 0.24198241287127722
#   0.44042452440873675 1.111865819490671]
#  ['House' 'Bahria Town Karachi' 'Karachi' -0.4227711783150659
#   -0.3542752068465506 0.33132095082749735]]

# %%
# Encode categorical features using one hot encoding
categorical_features = [0, 1, 2]
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(sparse_output=False), categorical_features)], remainder='passthrough')
ct = ct.fit(X)
X = ct.transform(X)
print(X)
# Out:
# [[0.0 1.0 0.0 ... -1.087524769501409 -1.148974938101838
#   -0.5849708515162284]
#  [0.0 1.0 0.0 ... -0.4227711783150659 -0.3542752068465506
#   -0.31347698415512454]
#  [0.0 0.0 1.0 ... 1.5714895952439636 1.235124255664024
#   0.09376381688653136]
#  ...
#  [0.0 0.0 1.0 ... -0.4227711783150659 -0.3542752068465506
#   0.09376381688653136]
#  [0.0 0.0 1.0 ... 0.24198241287127722 0.44042452440873675
#   1.111865819490671]
#  [0.0 0.0 1.0 ... -0.4227711783150659 -0.3542752068465506
#   0.33132095082749735]]

# %%
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
joblib.dump(model, 'model.pkl', compress=9)
# Out:
# ['model.pkl']
